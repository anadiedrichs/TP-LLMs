# %% [markdown]
# <a href="https://colab.research.google.com/github/anadiedrichs/TP-LLMs/blob/main/TP_LLMs_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Installation

# %%
# !pip install langchain
# !pip install langchain_community
# !pip install langchain-core
# !pip install PyPDF
# !pip install sentence-transformers
# !pip install chromadb
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.6.6)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.1)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.60)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.6.6)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.0)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.1.60)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (0.1.60)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (8.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-core) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain-core) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core) (2024.2.2)
# Requirement already satisfied: PyPDF in /usr/local/lib/python3.10/dist-packages (4.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from PyPDF) (4.11.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.41.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.40)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.7.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.29.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.3)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.16.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)

# %% [markdown]
# ### Load the libraries

# %%
import argparse
import os
import shutil
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
#from get_embedding_function import get_embedding_function
from langchain.vectorstores.chroma import Chroma

# %% [markdown]
# ## Environment variables

# %%
CHROMA_PATH = "chroma"
DATA_PATH = "data"

# CHROMA_DATA_PATH = "chroma_data/"
EMBED_MODEL = "all-MiniLM-L6-v2"
COLLECTION_NAME = "biblioteca"

# %% [markdown]
# ## Dataset

# %%
links = ["https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/32/Violencias%20por%20motivos%20de%20g%c3%a9nero%20-%20MMGyD.pdf",
         "https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/26/Perspectiva%20de%20g%c3%a9nero%20y%20diversidad%20-%20MMGyD.pdf",
         "https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/19/Masculinidades%20sin%20violencia%20-%20MMGyD.pdf",
         "https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/18/Igualdad%20en%20los%20cuidados.pdf",
         "https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/35/Diversidad%20-%20MMGyD.pdf"
         ]
titles = ["Violencia por motivos de género",
        "Perspectiva de género y diversidad",
        "Masculinidades sin violencia",
        "Igualdad en los cuidados",
        "Diversidad una perspectiva para la igualdad"]
file_name = ["violencia.pdf",
        "perspectiva.pdf",
        "masculinidades.pdf",
        "cuidados.pdf",
        "diversidad.pdf"]
pag_from = [14-1,14-1,14-1,14-1,12-1] # resto uno porque se indexa desde cero
pag_to = [85,97,30,98,87]

# %%
# create a pandas Dataframe using the previous information

import pandas as pd

data = {
    "title": titles,
    "link": links,
    "file_name": file_name,
    "pag_from": pag_from,
    "pag_to": pag_to,
}

df = pd.DataFrame(data)

print(df)
# Out:
#                                          title  \
# 0              Violencia por motivos de género
# 1           Perspectiva de género y diversidad
# 2                 Masculinidades sin violencia
# 3                     Igualdad en los cuidados
# 4  Diversidad una perspectiva para la igualdad
#
#                                                 link           file_name  \
# 0  https://editorial.mingeneros.gob.ar:8080/xmlui...       violencia.pdf
# 1  https://editorial.mingeneros.gob.ar:8080/xmlui...     perspectiva.pdf
# 2  https://editorial.mingeneros.gob.ar:8080/xmlui...  masculinidades.pdf
# 3  https://editorial.mingeneros.gob.ar:8080/xmlui...        cuidados.pdf
# 4  https://editorial.mingeneros.gob.ar:8080/xmlui...      diversidad.pdf
#
#    pag_from  pag_to
# 0        13      85
# 1        13      97
# 2        13      30
# 3        13      98
# 4        11      87

# %% [markdown]
# Descarga de los archivos PDF a directorio local DATA_PATH

# %%
# download pdfs using info from df variable and save then in data_path
import os

# Create the directory if it doesn't exist
os.makedirs(DATA_PATH, exist_ok=True)

# Download each PDF file
for index, row in df.iterrows():
    file_path = os.path.join(DATA_PATH, row["file_name"])
    # !wget -O {file_path} {row["link"]}
# Out:
# --2024-05-22 21:55:40--  https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/32/Violencias%20por%20motivos%20de%20g%c3%a9nero%20-%20MMGyD.pdf
# Resolving editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)... 181.209.31.64
# Connecting to editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)|181.209.31.64|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: 1087323 (1.0M) [application/pdf]
# Saving to: ‘data/violencia.pdf’
#
# data/violencia.pdf  100%[===================>]   1.04M  1.21MB/s    in 0.9s
#
# 2024-05-22 21:55:42 (1.21 MB/s) - ‘data/violencia.pdf’ saved [1087323/1087323]
#
# --2024-05-22 21:55:42--  https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/26/Perspectiva%20de%20g%c3%a9nero%20y%20diversidad%20-%20MMGyD.pdf
# Resolving editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)... 181.209.31.64
# Connecting to editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)|181.209.31.64|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: 3231581 (3.1M) [application/pdf]
# Saving to: ‘data/perspectiva.pdf’
#
# data/perspectiva.pd 100%[===================>]   3.08M  2.57MB/s    in 1.2s
#
# 2024-05-22 21:55:44 (2.57 MB/s) - ‘data/perspectiva.pdf’ saved [3231581/3231581]
#
# --2024-05-22 21:55:44--  https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/19/Masculinidades%20sin%20violencia%20-%20MMGyD.pdf
# Resolving editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)... 181.209.31.64
# Connecting to editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)|181.209.31.64|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: 467060 (456K) [application/pdf]
# Saving to: ‘data/masculinidades.pdf’
#
# data/masculinidades 100%[===================>] 456.11K   703KB/s    in 0.6s
#
# 2024-05-22 21:55:45 (703 KB/s) - ‘data/masculinidades.pdf’ saved [467060/467060]
#
# --2024-05-22 21:55:45--  https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/18/Igualdad%20en%20los%20cuidados.pdf
# Resolving editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)... 181.209.31.64
# Connecting to editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)|181.209.31.64|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: 579487 (566K) [application/pdf]
# Saving to: ‘data/cuidados.pdf’
#
# data/cuidados.pdf   100%[===================>] 565.91K   871KB/s    in 0.6s
#
# 2024-05-22 21:55:47 (871 KB/s) - ‘data/cuidados.pdf’ saved [579487/579487]
#
# --2024-05-22 21:55:47--  https://editorial.mingeneros.gob.ar:8080/xmlui/bitstream/handle/123456789/35/Diversidad%20-%20MMGyD.pdf
# Resolving editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)... 181.209.31.64
# Connecting to editorial.mingeneros.gob.ar (editorial.mingeneros.gob.ar)|181.209.31.64|:8080... connected.
# HTTP request sent, awaiting response... 200
# Length: 13206566 (13M) [application/pdf]
# Saving to: ‘data/diversidad.pdf’
#
# data/diversidad.pdf 100%[===================>]  12.59M  5.94MB/s    in 2.1s
#
# 2024-05-22 21:55:50 (5.94 MB/s) - ‘data/diversidad.pdf’ saved [13206566/13206566]

# %% [markdown]
# Check the downloaded pdf files

# %%
# !ls -la ./data/*
# Out:
# -rw-r--r-- 1 root root   579487 Oct 20  2023 ./data/cuidados.pdf
# -rw-r--r-- 1 root root   579487 Oct 20  2023 ./data/cuidados.txt
# -rw-r--r-- 1 root root 13206566 Jul  3  2023 ./data/diversidad.pdf
# -rw-r--r-- 1 root root 13206566 Jul  3  2023 ./data/diversidad.txt
# -rw-r--r-- 1 root root   467060 Oct 20  2023 ./data/masculinidades.pdf
# -rw-r--r-- 1 root root   467060 Oct 20  2023 ./data/masculinidades.txt
# -rw-r--r-- 1 root root  3231581 Aug 14  2023 ./data/perspectiva.pdf
# -rw-r--r-- 1 root root  3231581 Aug 14  2023 ./data/perspectiva.txt
# -rw-r--r-- 1 root root  1087323 Jul 10  2023 ./data/violencia.pdf
# -rw-r--r-- 1 root root  1087323 Jul 10  2023 ./data/violencia.txt

# %%
# Load the pdf files from DATA_PATH directory using df information. We have to load only from page number indicated in  pag_from to page number indicated in pag_to in df

from pypdf import PdfReader

# Load the PDF documents
documents = []

# For each document in my dataset
for index, row in df.iterrows():

    file_path = os.path.join(DATA_PATH, row["file_name"])
    reader = PdfReader(file_path)
    doc = reader.pages[row["pag_from"]:row["pag_to"]]

    #convert each page to a Document type with metadata
    pags = []
    i = 1
    for page in doc:
        pags.append(Document(page_content=page.extract_text(), metadata={'page':(i+row["pag_from"]),'source': row["file_name"] }))
        i += 1

    documents.append(pags)

# Print the number of documents loaded
print(f"Number of documents loaded: {len(documents)}")
# Out:
# Number of documents loaded: 5

# %% [markdown]
# Check the results for violencia.pdf

# %%
len(documents[0])
# Out:
# 72

# %%
documents[0][71]
# Out:
# Document(page_content="84Principios de Yogyakarta (2007). Principios sobre la aplicación de \nla legislación internacional de derechos humanos en relación con la \norientación sexual y la identidad de género. Disponible en: http://yog-\nyakartaprinciples.org/principles-sp/about/\nBlas Radi y Alejandra Sardá-Chandiramani (2016). Travesticidio / \ntransfemicidio: Coordenadas para pensar los crímenes de travestis y \nmujeres trans en Argentina. Publicación en el Boletín del Observato-\nrio de Género, https://www.aacademica.org/blas.radi/14.pdf\nRussell, Diana E.H. (2008). Femicidio: politizando el asesinato de mu-\njeres. Fortaleciendo la comprensión del femicidio: De la investigación \na la acción, Program for Appropriate Technology in Health (PATH), \nInterCambios, Medical Research Council of South Africa (MRC), and \nWorld Health Organization (WHO), http://alianzaintercambios.net/\nfiles/doc/1277249021_feminicidio-COMPLETO-01.pdf#page=43\nSegato, Rita (2016), La Guerra Contra las Mujeres. Madrid: Trafican-\ntes de Sueños, https://www.traficantes.net/sites/default/files/pdfs/\nmap45_segato_web.pdf\nSagot, Monserrat (2008), Estrategias para enfrentar la violencia \ncontra las mujeres: reflexiones feministas desde América Latina, \nAthenea Digital, Núm. 14, 215-228.\nWittig, M. El pensamiento heterosexual. Barcelona: GALES. (1992).\nViveros Vigoya, M. (2016). La interseccionalidad: una aproximación \nsituada a la dominación. Debate Feminista, 52, 1-17\nYuval-Davis, N. (2006). Intersectionality and feminist politics. Euro-\npean Journal of Women's Studies, 13(3), 193-209.", metadata={'page': 85, 'source': 'violencia.pdf'})

# %% [markdown]
# ## Preprocesamiento de texto
#
# Hay palabras separadas por guion como Observato-\nrio

# %%
# from the list documents, delete from the text the "-\n" characters

def remove_line_breaks(documents):
  for doc_list in documents:
    for doc in doc_list:
      doc.page_content = doc.page_content.replace("-\n", "")
  return documents

documents = remove_line_breaks(documents)

# %%
documents[0][71]
# Out:
# Document(page_content="84Principios de Yogyakarta (2007). Principios sobre la aplicación de \nla legislación internacional de derechos humanos en relación con la \norientación sexual y la identidad de género. Disponible en: http://yogyakartaprinciples.org/principles-sp/about/\nBlas Radi y Alejandra Sardá-Chandiramani (2016). Travesticidio / \ntransfemicidio: Coordenadas para pensar los crímenes de travestis y \nmujeres trans en Argentina. Publicación en el Boletín del Observatorio de Género, https://www.aacademica.org/blas.radi/14.pdf\nRussell, Diana E.H. (2008). Femicidio: politizando el asesinato de mujeres. Fortaleciendo la comprensión del femicidio: De la investigación \na la acción, Program for Appropriate Technology in Health (PATH), \nInterCambios, Medical Research Council of South Africa (MRC), and \nWorld Health Organization (WHO), http://alianzaintercambios.net/\nfiles/doc/1277249021_feminicidio-COMPLETO-01.pdf#page=43\nSegato, Rita (2016), La Guerra Contra las Mujeres. Madrid: Traficantes de Sueños, https://www.traficantes.net/sites/default/files/pdfs/\nmap45_segato_web.pdf\nSagot, Monserrat (2008), Estrategias para enfrentar la violencia \ncontra las mujeres: reflexiones feministas desde América Latina, \nAthenea Digital, Núm. 14, 215-228.\nWittig, M. El pensamiento heterosexual. Barcelona: GALES. (1992).\nViveros Vigoya, M. (2016). La interseccionalidad: una aproximación \nsituada a la dominación. Debate Feminista, 52, 1-17\nYuval-Davis, N. (2006). Intersectionality and feminist politics. European Journal of Women's Studies, 13(3), 193-209.", metadata={'page': 85, 'source': 'violencia.pdf'})

# %% [markdown]
# ## División de texto en secciones

# %%
# tabken from https://raw.githubusercontent.com/pixegami/rag-tutorial-v2/main/populate_database.py
def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

# %%
chunks = []

for doc_list in documents:
  chunks.append(split_documents(doc_list))

# %%
chunks
# Out:
# [[Document(page_content='13\nViolencias por motivos de género¿Qué son las violencias por motivos de \ngénero? \nLas violencias por motivos de género son una manifestación de las relaciones de poder históricamente desiguales entre los géneros. Esta perspectiva las enmarca como un problema social, cultural y político. Es decir, \ncuando hablamos de violencias por motivos de género no nos estamos refiriendo a un fenómeno individual, de pareja o intrafamiliar, sino a la subordinación social de mujeres, lesbianas, gays, bisexuales, trans, travestis, intersex, no binaries e identidades no heteronormadas (LGBTI+) en el marco \nde un orden de género y una política sexual que adquiere características \nparticulares en el actual escenario histórico.', metadata={'page': 14, 'source': 'violencia.pdf'}),
#   Document(page_content='particulares en el actual escenario histórico. \nDe esta manera, las violencias por motivos de género no se limitan a la violencia ejercida por algunos varones hacia determinadas mujeres y LGBTI+ \nsino que se estructuran como norma en la vida social. Si bien se pueden \nreconocer diversos tipos y modalidades de violencias -especificadas en la \nLey Nº 26.485 de Protección Integral para Prevenir, Sancionar y Erradicar la \nViolencia contra las Mujeres en los Ámbitos en que Desarrollen sus Relaciones Interpersonales (en adelante, Ley de Protección Integral de las Mujeres)1- es necesario recuperar esta noción estructural para comprender en \nprofundidad su origen, dinámicas y las posibilidades para su superación. \nLa matriz de las desigualdades de género es un sistema que organiza la', metadata={'page': 14, 'source': 'violencia.pdf'}),
#   Document(page_content='La matriz de las desigualdades de género es un sistema que organiza la \nsociedad de manera jerárquica y configura las relaciones sociales, políticas, culturales, económicas y ambientales: el patriarcado. Este sistema \noprime, subordina y domina a las mujeres y LGBTI+ y la violencia contra \nellxs es la expresión más explícita de esta dominación. \n1   Ley Nº 26.485 de Protección Integral para Prevenir, Sancionar y Erradicar la Violencia contra las Mujeres en los Ámbitos en que Desarrollen sus Relaciones Interpersonales. Disponible en http://servicios.infoleg.gob.ar/infolegInternet/ane xos/150000-154999/152155/texact.htm', metadata={'page': 14, 'source': 'violencia.pdf'}),
#   Document(page_content='14La relación jerárquica de los géneros hace que uno se posicione por encima de los otros,  ejerciendo el control y  autoridad en distintos ámbitos del \norden social y de la vida de las personas. Es por esto que toda conducta u \nomisión que atente contra la vida, libertad, dignidad, integridad psicológica, \nfísica, económica, patrimonial y la seguridad personal de mujeres y LGBTI+ \nes considerada violencia por motivos de género.\nAdemás, las violencias por motivos de género deben ser consideradas \ndesde una perspectiva integral, teniendo en cuenta la interseccionalidad,', metadata={'page': 15, 'source': 'violencia.pdf'}),
#   Document(page_content='desde una perspectiva integral, teniendo en cuenta la interseccionalidad, \nes decir, el cruce del género con otras categorías como la edad, clase social, orientación sexual, identidad de género, discapacidad, condición migrante,  pertenencia a comunidades indígenas, ruralidad, contextos de encierro, entre otras. La intersección de las violencias por motivos de género \ncon alguna o varias de estas categorías, agrava las situaciones de vulnerabilidad y constituye una dimensión fundamental para definir los abordajes \nde las políticas públicas.', metadata={'page': 15, 'source': 'violencia.pdf'}),
#   Document(page_content='15\nViolencias por motivos de género\n“La ideología de la diferencia sexual opera en nuestra cultura como una censura, en la medida en que oculta la opo sición que existe en el plano social entre los hombres y las \nmujeres poniendo a la naturaleza como su causa. Masculino/femenino, macho/hembra son categorías que sirven \npara disimular el hecho de que las diferencias sociales implican siempre un orden económico, político e ideológico”.Violencias por motivos de género\nVoces sobre las violencias por motivos de género\nDistintxs autorxs han abordado el tema de las violencias por motivos \nde géne ro. Sus investigaciones y la mirada que aportan sobre la problemática funcionan como puertas de entrada desde donde analizar \nel tema y sus distintas dimensiones.\n15', metadata={'page': 16, 'source': 'violencia.pdf'}),
#   Document(page_content='16\n16“La violencia contra las mujeres es un componente estruc tural del sistema de opresión de género. El uso de la violencia es no solo uno de los medios más efectivos para contro lar a las mujeres, sino también una de las expresiones más \nbrutales y explícitas de la dominación y la subordinación. \nLa posición de mujeres y hombres se organiza como una je rarquía en la que los hombres tienen control sobre los principales recursos de la sociedad y sobre las mujeres. Existen \nnumerosos soportes ideológicos, morales, políticos, eco nómicos y legales para el ejercicio de la autoridad de los \nvarones sobre las mujeres. Aunque estos soportes varían \nhistórica y culturalmente, el uso de la violencia constituye \nuna de las formas más predominantes y generalizadas que', metadata={'page': 17, 'source': 'violencia.pdf'}),
#   Document(page_content='una de las formas más predominantes y generalizadas que \nayudan al ejercicio de esa autoridad”.', metadata={'page': 17, 'source': 'violencia.pdf'}),
#   Document(page_content='17\nViolencias por motivos de género\nViolencias por motivos de género\n17“Nuestras vidas contravienen todo el plexo biopolítico al \ncontravenir el núcleo que articula los dispositivos que disciplinan el cuerpo individual con las regulaciones que contro lan el cuerpo poblacional: la sexualidad hetero-cis-normada. Esa impugnación al punto ciego de las tramas de poder, \nse paga con la sistemática y brutal exposición a la muerte. \nCuando esa impugnación se cruza con otras variables de \nopresión, como las de etnia y clase, todo se potencia, siendo \nlas cifras de travesticidios/transfemicidios su translucencia. \nSer travesti, ser indígena, ser pobre, se paga vendiendo el \npropio cuerpo, muriendo a los 37 años de hambre, de frío, de \nneumonía, asesinada, suicidada. Así se paga la excedencia', metadata={'page': 18, 'source': 'violencia.pdf'}),
#   Document(page_content='neumonía, asesinada, suicidada. Así se paga la excedencia \nde nuestras vidas que se afirman en la diferencia, en el límite poroso de los procesos normalizadores”.', metadata={'page': 18, 'source': 'violencia.pdf'}),
#   Document(page_content='18Nombrar es una forma de visibilizar\nLas formas en que se nombran las violencias implican una operación \nque diferencia y jerarquiza al incluir o excluir, por ejemplo, determina dos hechos o personas. Por eso han sido tan importantes los debates \nacerca de los alcances de las categorías que se utilizan para designar \ny comprender las violencias por motivos de género. \nEn nuestro país, esas formas de nombrar se han ido transformando: \nviolencia familiar, violencia contra las mujeres, violencia de género, \nviolencias por razones de género, violencias por motivos de género. \nTodas ellas han sido acompañadas por modificaciones en el ámbito \nestatal: legislaciones, organigramas y políticas públicas.', metadata={'page': 19, 'source': 'violencia.pdf'}),
#   Document(page_content='estatal: legislaciones, organigramas y políticas públicas. \nLas trasformaciones surgieron con la apertura de los procesos democráticos de la región en los cuales la violencia contra las mujeres \nocupó un lugar central tanto en las agendas de los movimientos feministas y en los organismos internacionales de derechos humanos, \ncomo en las definiciones de políticas públicas a nivel nacional. \nLa creación del Consejo Nacional de la Mujer en 1992 es el primer antecedente de institucionalización de la perspectiva de género y de la \nnecesidad de prevenir a nivel estatal las violencias contra las mujeres. \nEstos procesos fueron acompañados por la reforma constitucional', metadata={'page': 19, 'source': 'violencia.pdf'}),
#   Document(page_content='Estos procesos fueron acompañados por la reforma constitucional \nque introdujo con jerarquía constitucional diversos tratados de derechos humanos, entre los que es posible mencionar, la Convención \npara la Eliminación de todas las Formas de Discriminación contra la \nMujer de Naciones Unidas (CEDAW) y la Convención Americana sobre \nDerechos Humanos. A este listado se suma la ratificación de la Convención Interamericana para Prevenir, Sancionar y Erradicar la Violen cia contra la Mujer (Convención de Belém do Pará), instrumento que \nhasta la fecha no tiene jerarquía constitucional.\nEstos cambios legislativos a nivel nacional promovieron la creación \nde áreas específicas en los gobiernos locales, provinciales y la san ción de leyes que tuvieron como principal objeto la prevención de la', metadata={'page': 19, 'source': 'violencia.pdf'}),
#   Document(page_content='violencia familiar.', metadata={'page': 19, 'source': 'violencia.pdf'}),
#   Document(page_content='19\nViolencias por motivos de géneroLa sanción, en el año 2009, de la Ley Nº 26.485 de Protección Integral \nde las mujeres implicó un cambio de paradigma en el abordaje de la \nviolencia contra las mujeres, precisamente por la incorporación del \nconcepto de protección integral y por la referencia a otros tipos y mo dalidades de violencia que atraviesan las mujeres tanto en el ámbito \nfamiliar como en el ámbito público. \nDesde el Poder Legislativo se impulsaron otras iniciativas de rele vancia en el abordaje de las violencias de género en nuestro país: la \nsanción de la Ley de Prevención y Sanción de la Trata de Personas \ny Asistencia a sus Víctimas, las modificaciones de los agravantes a \nlos homicidios cuando mediare violencia de género, odio de género,', metadata={'page': 20, 'source': 'violencia.pdf'}),
#   Document(page_content='los homicidios cuando mediare violencia de género, odio de género, \norientación sexual o identidad de género (artículo 80, inciso 11 e inciso 4 del Código Penal de la Nación), entre otras.\nViolencias por motivos de género: la Ley N° 26.485 \nde Protección Integral de las Mujeres\nLa Ley Nº 26.485 de Protección Integral de las Mujeres, sancionada en \nel año 2009, es un hito normativo y un avance en materia de prevención, \nasistencia y abordaje de las violencias por motivos de género.\nSi bien la ley menciona a las mujeres, la problemática de las violen cias por motivos de género es más amplia y debe interpretarse a la \nluz de la Ley Nº 26.743 de Identidad de Género, una conquista his tórica de los movimientos LGBTI+ en materia de derechos para las', metadata={'page': 20, 'source': 'violencia.pdf'}),
#   Document(page_content='diversidades que permite abordar las violencias dirigidas al conjunto \nde las identidades de género.', metadata={'page': 20, 'source': 'violencia.pdf'}),
#   Document(page_content='20Esta ley marcó un cambio de paradigma en el abordaje de las violencias \npor motivos de género ya que fue la primera que planteó el tema de \nmanera integral. La normativa anterior, la Ley Nº 24.417 de Protección \ncontra la Violencia Familiar, estaba estrictamente ceñida al ámbito doméstico y no hacía alusión al género de las personas que se encontraban en esa situación. \nLa Ley de Protección Integral de las Mujeres fue sancionada en consonancia con los preceptos de la Convención de Belém do Pará2 y tiene \ncomo objeto promover y garantizar, entre otros: \n“a) La eliminación de la discriminación entre mujeres y varones en \ntodos los órdenes de la vida; b) El derecho de las mujeres a vivir \nuna vida sin violencia; c) Las condiciones aptas para sensibilizar y', metadata={'page': 21, 'source': 'violencia.pdf'}),
#   Document(page_content='22Violencia psicológica  \nSe trata de la violencia que causa daño emocional y disminución de \nla autoestima, perjudica y perturba el pleno desarrollo personal o que \nbusca degradar o controlar las acciones, comportamientos, creencias \ny decisiones mediante amenaza, acoso, hostigamiento, restricción, \nhumillación, deshonra, descrédito, manipulación, aislamiento. Incluye \nla culpabilización, vigilancia constante, exigencia de obediencia, sumisión, coerción verbal, persecución, insulto, indiferencia, abandono, \ncelos excesivos, chantaje, ridiculización, explotación y limitación del \nderecho de circulación o cualquier otro medio que cause perjuicio a su \nsalud psicológica y a la autodeterminación.\nMarcia tiene 23 años y convive con su pareja que es un', metadata={'page': 23, 'source': 'violencia.pdf'}),
#   Document(page_content='Marcia tiene 23 años y convive con su pareja que es un \njoven de 26. Cada almuerzo o cena -que ella cocina-, su \nnovio le refiere que su mamá cocina mejor y que le falta \nmucho por aprender. Marcia quiere trabajar fuera de la \ncasa pero su novio insiste en que no tiene ni la imagen \nadecuada -le dice gorda- ni tampoco la inteligencia para \naprender a hacer un trabajo. Le dice que para no ponerse en situaciones ridículas, mejor, se ocupe solo de \ntener limpia y ordenada la casa.\nViolencia sexual  \nEste tipo de violencia de género refiere a cualquier acción que implique \nla vulneración, en todas sus formas -con o sin acceso genital- del derecho de las mujeres y LGBTI+ a decidir voluntariamente acerca de su \nvida sexual o reproductiva a través de amenazas, coerción, uso de la', metadata={'page': 23, 'source': 'violencia.pdf'}),
#   Document(page_content='vida sexual o reproductiva a través de amenazas, coerción, uso de la \nfuerza o intimidación, incluyendo la violación dentro del matrimonio o \nde otras relaciones vinculares o de parentesco, exista o no convivencia, \nasí como la prostitución forzada, explotación, esclavitud, acoso, abuso \nsexual y trata de personas.', metadata={'page': 23, 'source': 'violencia.pdf'}),
#   Document(page_content='23\nViolencias por motivos de géneroRomina se siente muy angustiada y está cansada de Pablo, su marido. Desde que empezó a estudiar en la universidad su marido está muy celoso. Él se enoja si a la \nnoche no quiere tener relaciones sexuales y le dice que \nseguro es porque está con algún compañero. La noche \nanterior llegó a decirle que si no quería tener relaciones \nno le iba a dar plata para la comida de los nenes. \nViolencia económica y patrimonial \nSe trata de la violencia que se dirige a ejercer control de los recursos \neconómicos o patrimoniales de las mujeres y LGBTI+ cuando el agresor: \nse queda o controla sus bienes o propiedades; retiene, destruye o se \nlleva objetos, documentos personales, bienes, dinero, entre otros; limita', metadata={'page': 24, 'source': 'violencia.pdf'}),
#   Document(page_content='lleva objetos, documentos personales, bienes, dinero, entre otros; limita \nlos recursos económicos necesarios para tener una vida digna; controla \nlos ingresos, o cuando se cobra un menor salario por la misma tarea.\nDiana es una mujer de 46 años que vive con el padre de \nsus cuatro hijxs. Cobra la AUH y cada mes tiene una lista \nde compras de acuerdo a lo que van necesitando lxs chicxs. Su marido la acompaña siempre al cajero y le pide el \nmonto total porque, según él, ella no sabe organizarse. \nHace dos años que Diana no puede manejar ese dinero.\nViolencia simbólica \nSe presenta a través de patrones estereotipados, mensajes, valores, \níconos o signos que transmiten y reproducen dominación, desigualdad', metadata={'page': 24, 'source': 'violencia.pdf'}),
#   Document(page_content='íconos o signos que transmiten y reproducen dominación, desigualdad \ny discriminación en las relaciones sociales, naturalizando la subordinación de las mujeres y LGBTI+ en la sociedad.', metadata={'page': 24, 'source': 'violencia.pdf'}),
#   Document(page_content='24María estaba en una reunión de trabajo con tres colegas \nvarones, debatieron dos horas, abordaron distintos temas y cuando terminaron, uno de los colegas dijo “bueno, si los 3 estamos de acuerdo, firmamos”. Además \nde desconocerla -con su frase- como participante en la \ntoma de decisiones, trajeron un acta impresa en la que \nfiguraban los nombres de los 3 varones.\nViolencia política \nEste tipo de violencia apunta a menoscabar, anular, impedir, obstaculizar o restringir la participación política de las mujeres y LGBTI+, vulnerando el derecho a una vida política libre de violencias y/o el derecho a \nparticipar en los asuntos públicos y políticos en condiciones de igualdad con los varones.\n \nInés es maestra y desde que empezó a dar clases en la', metadata={'page': 25, 'source': 'violencia.pdf'}),
#   Document(page_content='Inés es maestra y desde que empezó a dar clases en la \nescuela primaria participa en el gremio de forma activa, \nademás de integrar la cooperadora. Llegó el momento \nde renovar las listas y las maestras conformaron una \npara presentar. La junta electoral la rechazó con el argumento de que eran todas mujeres.\nEn el artículo 6 se describen diversas modalidades en las que pue den manifestarse las violencias contra las mujeres y LGBTI+ en diferentes ámbitos:', metadata={'page': 25, 'source': 'violencia.pdf'}),
#   Document(page_content='25\nViolencias por motivos de géneroViolencia doméstica \nAquella ejercida por un/x integrante del grupo familiar, independientemente del espacio físico donde ocurra, que dañe la dignidad, el bienestar, la integridad física, psicológica, sexual, económica o patrimonial, \nla libertad, comprendiendo la libertad reproductiva y el derecho al pleno desarrollo de mujeres y LGBTI+. Se entiende por grupo familiar el \noriginado en el parentesco, sea por consanguinidad o por afinidad, el \nmatrimonio, las uniones de hecho y las parejas o noviazgos. Incluye las \nrelaciones vigentes o finalizadas, y no es requisito la convivencia.\n \nEmilia trabaja y vive en una quinta con sus dos hijxs y \nsu compañero Carlos. Lxs niñxs de Emilia no son hijxs', metadata={'page': 26, 'source': 'violencia.pdf'}),
#   Document(page_content='su compañero Carlos. Lxs niñxs de Emilia no son hijxs \nde Carlos y cada vez que el papá lxs viene a buscar, Car los insiste en que “hay algo” en cómo se miran y que lo \nhacen para provocarlo. La semana pasada, cuando lxs \nchicxs se fueron con su papá, Carlos empezó a darle \npatadas a la puerta mientras gritaba. Emilia se acercó \npidiéndole que se calme y Carlos la empujó hacia afuera \nde la casa, la tiró al piso, dio un portazo y le gritó que no \nse atreviera a volver a entrar y que no quería verla más \nni a ella ni a sus hijxs.\nViolencia institucional\nAquella realizada por funcionarixs, profesionales, personal y agentes \npertenecientes a cualquier órgano, ente o institución pública, que tenga como fin retardar, obstaculizar o impedir que las mujeres y LGBTI+', metadata={'page': 26, 'source': 'violencia.pdf'}),
#   Document(page_content='tengan acceso a las políticas públicas y ejerzan sus derechos. Quedan \ncomprendidas las que se ejercen en los partidos políticos, sindicatos, \norganizaciones empresariales, deportivas y de la sociedad civil.', metadata={'page': 26, 'source': 'violencia.pdf'}),
#   Document(page_content='26Rocío quiere anotarse en la nocturna para terminar el \nsecundario. Está entusiasmada porque una amiga le \ndijo que con el título podría estudiar una carrera en la \nuniversidad. Ella siempre soñó con ser médica. Pero \ncuando fue a inscribirse en la escuela no le aceptaron \nsu DNI porque dice que su nombre es Pablo. La directora le dijo “acá no queremos líos con gente como vos”.\nEl caso de la violencia institucional contra travestis y trans fue investigado en profundidad en el informe “La Revolución de las Mariposas” \n(2016), una publicación sobre la situación de la población trans en la \nCiudad Autónoma de Buenos Aires elaborada por el Programa de Género y Diversidad Sexual, la Fundación Divino Tesoro y el Bachillerato Popular Trans Mocha Celis. Con respecto a los ámbitos donde acontecen', metadata={'page': 27, 'source': 'violencia.pdf'}),
#   Document(page_content='las violencias identificadas, la calle es valorada como el ámbito más \nviolento por el 89,3% de las travestis y mujeres trans encuestadas. Las \ncomisarías fueron señaladas por el 40,9% de las personas consultadas \ny en tercer lugar la escuela, con el 32,1%. También fueron mencionadas \notras instituciones, como oficinas públicas en un 20,3% y los hospitales \nen un 18,2%. Asimismo, las cárceles son un ámbito de marcada violencia institucional contra las mujeres y LGBTI+3. \n3   En ese sentido, las normas contravencionales son una herramienta normativa que en \nla práctica pueden habilitar situaciones de violencia institucional. En función de eso, el \nMMGyD elaboró junto a la Secretaría de Derechos Humanos del Ministerio de Justicia', metadata={'page': 27, 'source': 'violencia.pdf'}),
#   Document(page_content='y Derechos Humanos de la Nación y el Ministerio de Seguridad de la Nación los “Lineamientos para la adecuación de normativas discriminatorias que criminalizan a mujeres \ncis, mujeres trans y travestis en los códigos contravencionales, de faltas y de convivencia \nen Argentina” con el objetivo de orientar el diseño e implementación de políticas públicas \ne informar futuras reformas a la normativa provincial y local, en el marco de las obligaciones que surgen de los tratados internacionales de derechos humanos ratificados \npor el Estado argentino. Disponible en: https://www.argentina.gob.ar/noticias/presentamos-los-lineamientos-para-la-adecuacion-de-normativas-discriminatorias-que', metadata={'page': 27, 'source': 'violencia.pdf'}),
#   Document(page_content='27\nViolencias por motivos de géneroViolencia laboral \nAquella que discrimina a mujeres y LGBTI+ en los ámbitos de trabajo \npúblicos o privados y que obstaculiza su acceso al empleo, contratación, ascenso, estabilidad o permanencia en el mismo, exigiendo requisitos sobre estado civil, maternidad, edad, apariencia física o la realización de test de embarazo. También constituye violencia de género \nen el ámbito laboral quebrantar el derecho de igual remuneración por \nigual tarea o función. Asimismo, incluye el hostigamiento psicológico \nen forma sistemática sobre un/x determinadx trabajador/x con el fin de \nlograr su exclusión laboral.\nCeleste tiene 21 años e ingresó recientemente al trabajo. \nSiendo su primera experiencia laboral, su director, quien', metadata={'page': 28, 'source': 'violencia.pdf'}),
#   Document(page_content='Siendo su primera experiencia laboral, su director, quien \nse encarga de repartir las tareas y supervisarlas, se enteró que es una mujer trans. A la hora de hablarle por su trabajo, tuvo gestos y conductas que la incomodaron, como \ncomentarios sexuales y preguntas sobre su vida personal.\nViolencia contra la libertad reproductiva \nAquella que vulnera el derecho de las mujeres y otras personas gestantes \na decidir libre y responsablemente el número de embarazos o el intervalo \nentre los nacimientos, de conformidad con la Ley Nº 25.673 de Creación \ndel Programa Nacional de Salud Sexual y Procreación Responsable.\n \nIrene se atiende en el hospital público de la ciudad y hace \nunos días hizo una consulta a su ginecólogo para una ligadura tubaria. El médico le dijo que es muy joven y que si', metadata={'page': 28, 'source': 'violencia.pdf'}),
#   Document(page_content='cambia de pareja quizá él quiera tener un hijx. Ella insistió \nen que estaba decidida por ese método anticonceptivo \npero el ginecólogo le escribió un papel, lo selló y le pidió \nque vuelva con esa autorización firmada por el marido.', metadata={'page': 28, 'source': 'violencia.pdf'}),
#   Document(page_content='28Violencia obstétrica \nAquella que se ejerce sobre el cuerpo y los procesos reproductivos de \nlas mujeres y otras personas gestantes, expresada en un trato deshumanizado, abuso de medicalización y patologización de los procesos \nnaturales, de conformidad con la Ley Nº 25.929.\n \nFátima tiene 30 años y cuatro hijas mujeres de las cua les dos nacieron por cesárea. Su última hija tiene 11 \nmeses. Cuando la tuvo, ingresó con muchas contracciones y sangrado al hospital. La partera de guardia le \ndijo. “¿Otra vez vos por acá? ¿Cuándo vas a aprender \na cerrar las piernas?” El médico obstetra la retó por no \ncuidar el embarazo y expresó “pensar que hay mujeres \nque no pueden tener hijos y ustedes vienen a parir como \nconejas y encima con complicaciones”.', metadata={'page': 29, 'source': 'violencia.pdf'}),
#   Document(page_content='conejas y encima con complicaciones”.\nEl Observatorio de Violencia Obstétrica de la agrupación feminista Las \nCasildas realizó la Encuesta de atención al parto/cesárea en los años \n2015-2016 para dimensionar los números de la violencia obstétrica a la \nluz de la Ley de Protección Integral de las Mujeres y Ley de Parto Respetado. La investigación realizada sobre 4939 nacimientos reveló que:\n ХA 3.3 de cada 10 mujeres y otras personas gestantes les hicieron \nsentir que ellxs o sus bebés corrían peligro.\n Х7 de cada 10 no tuvieron libertad de movimiento durante el parto.\n Х4 de cada 10 mujeres y otras personas gestantes no pudieron \nestar acompañadas durante el parto/cesárea. \n ХA 7 de cada 10 mujeres y otras personas gestantes les rompieron \nartificialmente la bolsa.', metadata={'page': 29, 'source': 'violencia.pdf'}),
#   Document(page_content='artificialmente la bolsa.\n Х7 de cada 10 mujeres y otras personas gestantes no saben qué \nprácticas realizaron sobre sus hijxs ni fue requerido su consentimiento.\n28', metadata={'page': 29, 'source': 'violencia.pdf'}),
#   Document(page_content='29\nViolencias por motivos de géneroViolencia mediática  \nEs la que se ejerce en la publicación o difusión de mensajes e imágenes \nestereotipadas a través de cualquier medio masivo de comunicación \nque promueva la explotación de mujeres y LGBTI+ o sus imágenes, injurie, difame, discrimine, deshonre, humille o atente contra su dignidad, \ncomo así también su utilización en mensajes e imágenes pornográficas, legitimando la desigualdad de trato o la construcción de patrones \nsocioculturales reproductores de la desigualdad o generadores de violencias de género.\nEn un diario de tirada nacional se relata la detención de \nuna ex policía de nombre Laura, señalada como la responsable de una serie de robos de autos. De la nota surgen \ndetalles sobre la vida personal de la mujer y como foto de', metadata={'page': 30, 'source': 'violencia.pdf'}),
#   Document(page_content='detalles sobre la vida personal de la mujer y como foto de \nportada aparece en una playa en traje de baño junto a un \nepígrafe que se refiere a ella como “la policía sexy”.\nViolencia en el espacio público \nAquella ejercida contra las mujeres y LGBTI+ por una o más personas \nen lugares públicos o de acceso público, como medios de transporte o \ncentros comerciales, a través de conductas o expresiones verbales o \nno verbales con connotación sexual, que afecten o dañen su dignidad, \nintegridad, libertad, libre circulación o permanencia y/o generen un ambiente hostil u ofensivo.\nMartina es una joven trans que con su amiga Noe van \ntodas las tardes a estudiar a la casa de Cami. En las \núltimas semanas un grupo de chicos del barrio se paran', metadata={'page': 30, 'source': 'violencia.pdf'}),
#   Document(page_content='La imagen que se muestra a continuación es muy elocuente porque \ngrafica cómo se van erigiendo, sobre una base invisible y naturalizada de prácticas violentas, otras formas de violencia más visibles. En la \npunta, el asesinato, la agresión física, la violación, el abuso sexual, los \ngritos, las amenazas, el insulto. Por debajo, invisible a los ojos de lxs \ndemás: las humillaciones, el desprecio, el chantaje emocional, la culpa, \nel humor sexista o la anulación.\n31', metadata={'page': 32, 'source': 'violencia.pdf'}),
#   Document(page_content='32\n32', metadata={'page': 33, 'source': 'violencia.pdf'}),
#   Document(page_content='33\nViolencias por motivos de géneroCada año, miles de personas en el mundo son víctimas de violencias \nextremas por motivos de género. Ellas son la última expresión de una \ncantidad de gestos y acciones de diversa gravedad que están legitimadas y son toleradas socialmente en la vida cotidiana y que, si bien en su \nmayoría no configuran delitos, son agresiones motivadas en el género. \nEstas diferentes violencias son la antesala de las agresiones graves y \nde las extremas, que sí están tipificadas en el Código Penal.\n33“No me gusta que pases tanto tiempo con tus amigas, \nno son buena influencia”.\n“Vos no sabés hacerlo, dejá que lo resuelvo yo”.\n“¿Así vas a salir? Estás gorda para usar ese vestido”.\n“Tu nombre es Ariel, no Rocío”.\n“Bueno, hay que ver quién lidera la negociación con', metadata={'page': 34, 'source': 'violencia.pdf'}),
#   Document(page_content='“Bueno, hay que ver quién lidera la negociación con \nla empresa. ¿Lo definimos en el partido de fútbol \ndel domingo?”\n“Mejor quedate en casa así podés estar más con lxs \nchicxs y ocuparte de la familia”.', metadata={'page': 34, 'source': 'violencia.pdf'}),
#   Document(page_content='3434Las violencias invisibles, esas que toleramos y con las que convivi mos, están en la base de un sistema que relega e ignora los derechos \nde mujeres y LGBTI+. Las violencias por motivos de género, sean suti les o explícitas, visibles o invisibilizadas, afectan y coartan las trayectorias de vida de las personas. \nLa Campaña Argentina Unida Contra las Violencias de Género del \nMMGyD, tiene como objetivo promover relaciones sociales más igualitarias entre los géneros por medio de acciones de alcance nacional, con una perspectiva federal e interseccional. A través del trabajo \nterritorial, publicaciones, talleres, materiales de difusión y productos \naudiovisuales, la campaña recorre el país convocando a todas, todes \ny todos a sumarse para construir una sociedad más justa.', metadata={'page': 35, 'source': 'violencia.pdf'}),
#   Document(page_content='y todos a sumarse para construir una sociedad más justa.\nTodxs podemos aportar al cambio cultural necesario \npara vivir una vida libre de violencias.\nLos materiales de la campaña se pueden descargar desde acá:', metadata={'page': 35, 'source': 'violencia.pdf'}),
#   Document(page_content='35\nViolencias por motivos de género¿De qué hablamos cuando decimos “señales \ntempranas”?4 \nLas señales tempranas son indicadores que facilitan la detección de \nsituaciones de violencia por motivos de género y que sirven para evitar situaciones de mayor riesgo a través de intervenciones oportunas. \nAlgunas pautas para realizar estas intervenciones y prevenir situaciones de violencia de género son la escucha activa, el acompañamiento \nintegral, la información adecuada para realizar una denuncia y el co nocimiento de los indicadores de riesgo. A continuación, describiremos brevemente cada uno de estos elementos.\nLa escucha activa\nEn el primer encuentro con una persona que podría estar atravesando \nuna situación de violencia por motivos de género el objetivo principal', metadata={'page': 36, 'source': 'violencia.pdf'}),
#   Document(page_content='una situación de violencia por motivos de género el objetivo principal \nserá acompañarla en el proceso para salir de esa situación. \nUna actitud de escucha activa tiene como finalidad generar un encuentro donde la persona pueda sentirse comprendida, segura, en \nconfianza y generar las condiciones para que pueda expresarse y no \nsentirse juzgada.\nEn ese sentido, es importante no usar lenguaje estigmatizante y preguntarle a la persona cómo desea ser nombrada, es decir, sin asumir \nla identidad o expresión de género y respetando los pronombres con \nlos que se identifica.\n4   Contenido extraído del material “Guía de herramientas para la detección de señales', metadata={'page': 36, 'source': 'violencia.pdf'}),
#   Document(page_content='tempranas de las violencias por motivos de género” del sello Mingeneros del Minis terio de las Mujeres, Géneros y Diversidad de la Nación. Disponible en https://www.\nargentina.gob.ar/sites/default/files/guia_de_herramientas_para_la_deteccion_de_senales_tempranas_de_las_violencias_por_motivos_de_genero.pdf', metadata={'page': 36, 'source': 'violencia.pdf'}),
#   Document(page_content='36Asimismo, es aconsejable no utilizar la palabra víctima porque representa un lugar de pasividad en el que se está negando su capacidad \nde agencia. Además, es una categoría que puede ser considerada \ncomo una característica de la personalidad de quien atraviesa la si tuación de violencia de género.\nLa escucha activa también implica no realizar interpretaciones sobre lo \nque está atravesando la otra persona ya que esto puede generar expulsión, resistencia y hasta poner en riesgo la continuidad del acompañamiento. Una manera de evitar este resultado no deseado es no dar indicaciones sobre qué hay que hacer o de qué forma hay que proceder sino \ngenerar acuerdos con la persona en base a sus deseos y posibilidades.', metadata={'page': 37, 'source': 'violencia.pdf'}),
#   Document(page_content='generar acuerdos con la persona en base a sus deseos y posibilidades.\nUna escucha activa incluye no poner en duda lo que se está contando. En su lugar, es recomendable preguntar sobre la historia de vida, \nel entorno, las redes de contención familiares y/o comunitarias para \nidentificar los vínculos de referencia y apoyo que la persona refiere. \nAsimismo, es clave atender a la gestualidad y lo que dice el cuerpo de \nla persona en situación de violencia, ser pacientes con sus tiempos y \nrespetar su confidencialidad y privacidad.\nEl acompañamiento\nEl acompañamiento se construye de manera integral con cada persona. Como cada situación es diferente, las intervenciones que se \nrealicen deben ser situadas, respetando la singularidad de la persona', metadata={'page': 37, 'source': 'violencia.pdf'}),
#   Document(page_content='realicen deben ser situadas, respetando la singularidad de la persona \nque se acompaña. Es fundamental contener, derivar y/o articular con \notros organismos del Estado y para ello se debe contar con informa ción actualizada y pertinente.\nSe trata de sostener y acompañar un proceso a través del cual las \npersonas puedan recuperar la posibilidad de decidir en torno a su proyecto de vida, cuerpo, salud, entre otros aspectos. Para llevar adelante \neste proceso será primordial que la persona se sienta contenida y que \nse construya un vínculo de confianza que permita conocer su historia \ny reconocer las violencias que atraviesa, así como las posibilidades \nde construir un nuevo proyecto de vida.', metadata={'page': 37, 'source': 'violencia.pdf'}),
#   Document(page_content='37\nViolencias por motivos de géneroLa denuncia\nExiste la creencia generalizada de que las personas en situación de \nviolencia de género deben siempre realizar una denuncia policial y/o \njudicial. Sin embargo, debe presentarse como una opción dentro de \nun abanico de posibilidades y también un derecho, pero nunca como \nuna obligación.\nLa denuncia policial y/o judicial es personal, es decir, quien decide si \nse realiza o no es la persona que atraviesa o atravesó la situación de \nviolencia. Las personas que acompañan deben brindar información \nsobre las consecuencias y los requerimientos de esta posibilidad.\nEn definitiva, la denuncia forma parte de una estrategia mayor de \nacompañamiento que se construye junto a la persona en situación de \nviolencia por motivos de género.', metadata={'page': 38, 'source': 'violencia.pdf'}),
#   Document(page_content='38Mitos sobre las violencias por motivos \nde género\nLos mitos sobre las violencias de género son creencias populares es tereotipadas que se sostienen a lo largo del tiempo. La complejidad \nde la vigencia y propagación de los mitos o falsas creencias sobre \nlas violencias de género es que las naturalizan y las relacionan con \nlo inevitable, lo instintivo, desdibujando su carácter estructural y la \nposibilidad de modificarlos. \nAl mismo tiempo, las violencias de género suelen ser ubicadas como una \nproblemática de una determinada clase social, justificadas en la falta de \neducación o en casos aislados, lo que evita comprender la problemática \ncomo una cuestión pública y social (González Prado - Yanes, 2013).', metadata={'page': 39, 'source': 'violencia.pdf'}),
#   Document(page_content='como una cuestión pública y social (González Prado - Yanes, 2013).\nEs muy importante reflexionar sobre estas creencias, hacerse preguntas y contar con la información precisa para poder desmontarlas. A \ncontinuación, presentamos ocho de los mitos más escuchados, junto \na información útil para desarmar cada uno de ellos.\nMito 1: "¿Por qué se quedan?" \nSi las mujeres no se van de sus casas es porque tan mal no están.\nLa dependencia económica, la falta de relaciones afectivas donde \napoyarse y el estado emocional en el que se encuentran las mujeres \nque se encuentran en una situación de violencias son, muchas veces, \nlos motivos por los cuales se vuelve muy complejo desarticular un \ncontexto de violencia.', metadata={'page': 39, 'source': 'violencia.pdf'}),
#   Document(page_content='contexto de violencia. \nRetomando las definiciones de tipos de violencias , la violencia psicológica comprende la manipulación, el aislamiento, la culpabilización, \nla vigilancia constante, la exigencia de obediencia, sumisión, inclusive \nla indiferencia o abandono que suelen afectar la salud psicológica y \nla autodeterminación.', metadata={'page': 39, 'source': 'violencia.pdf'}),
#   Document(page_content='39\nViolencias por motivos de géneroMuchas veces este mito se asocia a otros como “no se va porque \nla mantiene” o porque “sus amigxs o familia no la quieren” como si \nla dependencia económica y afectiva fuera “culpa” de la persona en \nsituación de violencia de género.\nMito 2: "Muchas denuncias son falsas" \nLas mujeres utilizan las denuncias como venganza hacia sus exparejas o para tener una ventaja en los procesos de separación y divorcio.\nEste es uno de los mitos más extendidos que no solo se desmiente \nestadísticamente, ya que las denuncias falsas son extremadamente \ninusuales, sino que desconoce los inmensos costos que implica el \nacto de denunciar: los problemas familiares, laborales, el miedo, los', metadata={'page': 40, 'source': 'violencia.pdf'}),
#   Document(page_content='acto de denunciar: los problemas familiares, laborales, el miedo, los \nseñalamientos, los ataques, las decisiones adversas y la revictimiza ción institucional.5\n \nMito 3: "Le pasa a otras" \nLas mujeres en situación de violencia de género tienen características \nconcretas: son pasivas, sumisas, con baja autoestima, sin trabajo remunerado, en situación de pobreza.\nCualquier mujer puede atravesar una situación de violencia de género. \nNo hay un perfil de mujer que tiende a ser más o menos maltratada o \nagredida. Esta idea estigmatiza a quienes están en esa situación y no \nles da credibilidad a lxs que no cumplen con el estereotipo.\n5   Según informa la Oficina de Violencia Doméstica (OVD) de la Corte Suprema de', metadata={'page': 40, 'source': 'violencia.pdf'}),
#   Document(page_content='Justicia de la Nación, de los 114.693 casos atendidos desde el 15 de septiembre de \n2008 hasta el 31 de mayo del 2020, solo en una ocasión se constató y condenó a una \npersona por haber hecho una denuncia falsa.', metadata={'page': 40, 'source': 'violencia.pdf'}),
# ...
#   Document(page_content='76\nPodés consultar todas las políticas y programas del MMGyD en\nTambién podés consultarlo acá: www.argentina.gob.ar/generos', metadata={'page': 77, 'source': 'diversidad.pdf'}),
#   Document(page_content='77\nDiversidad. Una perspectiva para la igualdadPalabras finales\nVivimos en un país donde las trayectorias de vida de LGBTI+ encontraron eco en el reconocimiento de derechos y también en transformaciones sociales. Muchas de las condiciones de exclusión que \nmarcaron las niñeces y adolescencias de LGBTI+ que hoy son adultxs \nempezaron, de a poco, a cambiar de manera sostenida.\nLa perspectiva de diversidad es un tema central en la agenda política. \nLa creación del Ministerio de las Mujeres, Géneros y Diversidad de \nla Nación, y dentro de su estructura, la Subsecretaría de Políticas de \nDiversidad, es una muestra clara de ello.\nA 45 años del último golpe de Estado cívico militar, la perspectiva de', metadata={'page': 78, 'source': 'diversidad.pdf'}),
#   Document(page_content='A 45 años del último golpe de Estado cívico militar, la perspectiva de \ndiversidad es un gran logro de nuestra vida democrática. Con el es fuerzo y el trabajo de las organizaciones y de las gestiones de gobierno comprometidas, logramos avanzar en materia de garantía de \nderechos de LGBTI+. Es también un logro que implica una transformación semántica, una discusión por los sentidos de la democracia. \nY el sentido que queremos darle a la democracia es el de la igualdad \nen la diversidad.\nContamos con que esta publicación pueda ser un insumo para consolidar el camino de ampliación y garantía de los derechos, mediante \nla crítica y la reflexión sobre las relaciones de poder aún vigentes en \nnuestra sociedad.\nHemos avanzado de manera significativa y seguiremos impulsando la', metadata={'page': 78, 'source': 'diversidad.pdf'}),
#   Document(page_content='Hemos avanzado de manera significativa y seguiremos impulsando la \ntransformación de las instituciones en clave de diversidad, para construir un Estado más parecido a la sociedad de la que forma parte, para \nque la perspectiva transfeminista atraviese todas y cada una de las \npolíticas públicas que se diseñen e implementen, para garantizar el \nacceso a derechos de todas, todos, todes y para consolidar un país \nmás justo, democrático, diverso e igualitario.', metadata={'page': 78, 'source': 'diversidad.pdf'}),
#   Document(page_content='78', metadata={'page': 79, 'source': 'diversidad.pdf'}),
#   Document(page_content='79\nDiversidad. Una perspectiva para la igualdad\nBibliografía\nAgencia Presentes (2016). Entrevista inédita a Diana Sacayán: “Hablo \ndesde el núcleo travesti politizado”. Disponible en: https://agenciapresentes.org/2016/12/19/entrevista-inedita-diana-sacayan-hablo-desde-nucleo-travesti-mas-politizado/\nÁlvarez, Ana y Fernández, Josefina (2021). Nadia y sus amigas. Un diálogo entre Nadia
#   Document(page_content='(artículos 2.2 y 3); la Convención sobre los Derechos del Niño (CDN) \n(artículo 2); y la Convención sobre la Eliminación de Todas las Formas \nde Discriminación contra la Mujer (CEDAW) (artículos 2, 3 y ss.). \n ХLa Ley Nº 26.485 de Protección Integral para Prevenir, Sancionar y \nErradicar la Violencia contra las Mujeres en los ámbitos en que desa rrollen sus relaciones interpersonales.\n ХLa Ley Nº 26.510 de Educación Sexual Integral establece el derecho de las infancias y adolescencias a recibir educación sexual inte gral en todos los establecimientos educativos del país. \n ХLa Ley N° 27.499, Ley Micaela, que establece la capacitación obligatoria en la temática de género y diversidad para todas las personas \nque se desempeñen en la función pública.', metadata={'page': 85, 'source': 'diversidad.pdf'}),
#   Document(page_content='que se desempeñen en la función pública. \n ХLa Ley Nº 27.610 de Acceso a la Interrupción Voluntaria del Emba razo para todas las personas gestantes, reconociendo los derechos y \nla autonomía de mujeres, lesbianas, varones trans y no binaries.', metadata={'page': 85, 'source': 'diversidad.pdf'}),
#   Document(page_content='85\nDiversidad. Una perspectiva para la igualdad ХLa Ley Nº 27.611 de Atención y Cuidado Integral de la Salud durante el Embarazo y la Primera Infancia. \nEn el marco legislativo nacional, desde la perspectiva de la diversidad \nse destaca19:\n ХLa Ley N°26.618, Ley de Matrimonio Igualitario.\n ХLa Ley Nº 26.473 de Identidad de Género (LIG).\n ХEl Decreto Presidencial N° 721/20 y la Ley N° 27.636 de Promoción \ndel acceso al empleo formal para personas travestis, transexuales y \ntransgénero “Diana Sacayán - Lohana Berkins”. \n ХLa Ley Nº 27.635 de equidad en la representación de los géneros \nen los servicios de comunicación de la República Argentina establece \nque deberá garantizarse una representación de travestis, transexua les, transgénero e intersexuales en una proporción no inferior al 1% de', metadata={'page': 86, 'source': 'diversidad.pdf'}),
#   Document(page_content='la totalidad del personal.\n ХEl Decreto N° 476/2021 incorporó una tercera opción documentaria \nen la categoría “sexo” en el Documento Nacional de Identidad y en el \nPasaporte.\n19 Otras leyes que incorporan perspectiva de diversidad son: la Ley Nº 26.657 Derecho \na la Protección de la Salud Mental; Ley Nº 26.862 Acceso integral a los procedimientos \ny técnicas médico-asistenciales de reproducción médicamente asistida; y la Ley Nº \n26.529, de Derechos del Paciente en su Relación con los Profesionales e Instituciones \nde la Salud, entre otras.', metadata={'page': 86, 'source': 'diversidad.pdf'}),
#   Document(page_content='DIVERSIDAD\nUna perspectiva \npara la igualdad', metadata={'page': 87, 'source': 'diversidad.pdf'})]]

# %%
# unlist chunks
chunks  = [val for sublist in chunks for val in sublist]

# %%
type(chunks[0])
# Out:
# langchain_core.documents.base.Document

# %%
chunks[0].metadata
# Out:
# {'page': 14, 'source': 'violencia.pdf'}

# %%
# taken from https://raw.githubusercontent.com/pixegami/rag-tutorial-v2/main/populate_database.py
def calculate_chunk_ids(chunks):

    # This will create IDs like "data/violencia.pdf:16:2"
    # Page Source : Page Number : Chunk Index

    last_page_id = None
    current_chunk_index = 0

    for chunk in chunks:
        source = chunk.metadata.get("source")
        page = chunk.metadata.get("page")
        current_page_id = f"{source}:{page}"

        # If the page ID is the same as the last one, increment the index.
        if current_page_id == last_page_id:
            current_chunk_index += 1
        else:
            current_chunk_index = 0

        # Calculate the chunk ID.
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        last_page_id = current_page_id

        # Add it to the page meta-data.
        chunk.metadata["id"] = chunk_id

    return chunks

# %% [markdown]
# ## Creación y configuración de base de datos

# %% [markdown]
# ### Limpiar la base de datos

# %%
def clear_database():
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

# %%
clear_database()

# %% [markdown]
# ### get_embedding_function()

# %%
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
# create the open-source embedding function
def get_embedding_function():
    embeddings = SentenceTransformerEmbeddings(model_name=EMBED_MODEL)
    return embeddings

# %% [markdown]
# ### Creación de base de datos usando ChromaDB

# %%
# Load the existing database.
db = Chroma( persist_directory=CHROMA_PATH, embedding_function=get_embedding_function())

#os.chmod(CHROMA_PATH, 777)  # Otorga permisos de lectura y escritura
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# !ls
# Out:
# chroma	data  sample_data

# %%
# Calculate Page IDs.
chunks_with_ids = calculate_chunk_ids(chunks)

# %%
len(chunks_with_ids)
# Out:
# 664

# %%
len(chunks)
# Out:
# 664

# %%
chunks_with_ids[0]
# Out:
# Document(page_content='13\nViolencias por motivos de género¿Qué son las violencias por motivos de \ngénero? \nLas violencias por motivos de género son una manifestación de las relaciones de poder históricamente desiguales entre los géneros. Esta perspectiva las enmarca como un problema social, cultural y político. Es decir, \ncuando hablamos de violencias por motivos de género no nos estamos refiriendo a un fenómeno individual, de pareja o intrafamiliar, sino a la subordinación social de mujeres, lesbianas, gays, bisexuales, trans, travestis, intersex, no binaries e identidades no heteronormadas (LGBTI+) en el marco \nde un orden de género y una política sexual que adquiere características \nparticulares en el actual escenario histórico.', metadata={'page': 14, 'source': 'violencia.pdf', 'id': 'violencia.pdf:14:0'})

# %%
ids = [chunk.metadata["id"] for chunk in chunks_with_ids]

# %%
ids
# Out:
# ['violencia.pdf:14:0',
#  'violencia.pdf:14:1',
#  'violencia.pdf:14:2',
#  'violencia.pdf:15:0',
#  'violencia.pdf:15:1',
#  'violencia.pdf:16:0',
#  'violencia.pdf:17:0',
#  'violencia.pdf:17:1',
#  'violencia.pdf:18:0',
#  'violencia.pdf:18:1',
#  'violencia.pdf:19:0',
#  'violencia.pdf:19:1',
#  'violencia.pdf:19:2',
#  'violencia.pdf:19:3',
#  'violencia.pdf:20:0',
#  'violencia.pdf:20:1',
#  'violencia.pdf:20:2',
#  'violencia.pdf:21:0',
#  'violencia.pdf:21:1',
#  'violencia.pdf:21:2',
#  'violencia.pdf:21:3',
#  'violencia.pdf:22:0',
#  'violencia.pdf:22:1',
#  'violencia.pdf:23:0',
#  'violencia.pdf:23:1',
#  'violencia.pdf:23:2',
#  'violencia.pdf:24:0',
#  'violencia.pdf:24:1',
#  'violencia.pdf:24:2',
#  'violencia.pdf:25:0',
#  'violencia.pdf:25:1',
#  'violencia.pdf:26:0',
#  'violencia.pdf:26:1',
#  'violencia.pdf:26:2',
#  'violencia.pdf:27:0',
#  'violencia.pdf:27:1',
#  'violencia.pdf:27:2',
#  'violencia.pdf:28:0',
#  'violencia.pdf:28:1',
#  'violencia.pdf:28:2',
#  'violencia.pdf:29:0',
#  'violencia.pdf:29:1',
#  'violencia.pdf:29:2',
#  'violencia.pdf:30:0',
#  'violencia.pdf:30:1',
#  'violencia.pdf:30:2',
#  'violencia.pdf:31:0',
#  'violencia.pdf:31:1',
#  'violencia.pdf:31:2',
#  'violencia.pdf:32:0',
#  'violencia.pdf:32:1',
#  'violencia.pdf:32:2',
#  'violencia.pdf:33:0',
#  'violencia.pdf:34:0',
#  'violencia.pdf:34:1',
#  'violencia.pdf:35:0',
#  'violencia.pdf:35:1',
#  'violencia.pdf:36:0',
#  'violencia.pdf:36:1',
#  'violencia.pdf:36:2',
#  'violencia.pdf:37:0',
#  'violencia.pdf:37:1',
#  'violencia.pdf:37:2',
#  'violencia.pdf:38:0',
#  'violencia.pdf:39:0',
#  'violencia.pdf:39:1',
#  'violencia.pdf:39:2',
#  'violencia.pdf:40:0',
#  'violencia.pdf:40:1',
#  'violencia.pdf:40:2',
#  'violencia.pdf:41:0',
#  'violencia.pdf:41:1',
#  'violencia.pdf:42:0',
#  'violencia.pdf:43:0',
#  'violencia.pdf:43:1',
#  'violencia.pdf:44:0',
#  'violencia.pdf:44:1',
#  'violencia.pdf:44:2',
#  'violencia.pdf:45:0',
#  'violencia.pdf:45:1',
#  'violencia.pdf:45:2',
#  'violencia.pdf:46:0',
#  'violencia.pdf:46:1',
#  'violencia.pdf:47:0',
#  'violencia.pdf:48:0',
#  'violencia.pdf:48:1',
#  'violencia.pdf:48:2',
#  'violencia.pdf:49:0',
#  'violencia.pdf:49:1',
#  'violencia.pdf:49:2',
#  'violencia.pdf:50:0',
#  'violencia.pdf:50:1',
#  'violencia.pdf:50:2',
#  'violencia.pdf:51:0',
#  'violencia.pdf:51:1',
#  'violencia.pdf:51:2',
#  'violencia.pdf:52:0',
#  'violencia.pdf:52:1',
#  'violencia.pdf:52:2',
#  'violencia.pdf:53:0',
#  'violencia.pdf:53:1',
#  'violencia.pdf:54:0',
#  'violencia.pdf:54:1',
#  'violencia.pdf:54:2',
#  'violencia.pdf:55:0',
#  'violencia.pdf:55:1',
#  'violencia.pdf:56:0',
#  'violencia.pdf:56:1',
#  'violencia.pdf:56:2',
#  'violencia.pdf:57:0',
#  'violencia.pdf:57:1',
#  'violencia.pdf:58:0',
#  'violencia.pdf:58:1',
#  'violencia.pdf:58:2',
#  'violencia.pdf:59:0',
#  'violencia.pdf:59:1',
#  'violencia.pdf:59:2',
#  'violencia.pdf:60:0',
#  'violencia.pdf:60:1',
#  'violencia.pdf:60:2',
#  'violencia.pdf:61:0',
#  'violencia.pdf:61:1',
#  'violencia.pdf:61:2',
#  'violencia.pdf:62:0',
#  'violencia.pdf:62:1',
#  'violencia.pdf:63:0',
#  'violencia.pdf:63:1',
#  'violencia.pdf:64:0',
#  'violencia.pdf:64:1',
#  'violencia.pdf:65:0',
#  'violencia.pdf:65:1',
#  'violencia.pdf:66:0',
#  'violencia.pdf:67:0',
#  'violencia.pdf:67:1',
#  'violencia.pdf:68:0',
#  'violencia.pdf:68:1',
#  'violencia.pdf:69:0',
#  'violencia.pdf:69:1',
#  'violencia.pdf:70:0',
#  'violencia.pdf:70:1',
#  'violencia.pdf:71:0',
#  'violencia.pdf:71:1',
#  'violencia.pdf:72:0',
#  'violencia.pdf:72:1',
#  'violencia.pdf:73:0',
#  'violencia.pdf:73:1',
#  'violencia.pdf:74:0',
#  'violencia.pdf:74:1',
#  'violencia.pdf:75:0',
#  'violencia.pdf:76:0',
#  'violencia.pdf:76:1',
#  'violencia.pdf:76:2',
#  'violencia.pdf:77:0',
#  'violencia.pdf:77:1',
#  'violencia.pdf:77:2',
#  'violencia.pdf:77:3',
#  'violencia.pdf:78:0',
#  'violencia.pdf:78:1',
#  'violencia.pdf:78:2',
#  'violencia.pdf:79:0',
#  'violencia.pdf:79:1',
#  'violencia.pdf:79:2',
#  'violencia.pdf:80:0',
#  'violencia.pdf:81:0',
#  'violencia.pdf:81:1',
#  'violencia.pdf:81:2',
#  'violencia.pdf:82:0',
#  'violencia.pdf:82:1',
#  'violencia.pdf:82:2',
#  'violencia.pdf:83:0',
#  'violencia.pdf:83:1',
#  'violencia.pdf:83:2',
#  'violencia.pdf:84:0',
#  'violencia.pdf:84:1',
#  'violencia.pdf:84:2',
#  'violencia.pdf:85:0',
#  'violencia.pdf:85:1',
#  'violencia.pdf:85:2',
#  'perspectiva.pdf:14:0',
#  'perspectiva.pdf:14:1',
#  'perspectiva.pdf:14:2',
#  'perspectiva.pdf:15:0',
#  'perspectiva.pdf:15:1',
#  'perspectiva.pdf:16:0',
#  'perspectiva.pdf:16:1',
#  'perspectiva.pdf:17:0',
#  'perspectiva.pdf:17:1',
#  'perspectiva.pdf:17:2',
#  'perspectiva.pdf:18:0',
#  'perspectiva.pdf:18:1',
#  'perspectiva.pdf:18:2',
#  'perspectiva.pdf:19:0',
#  'perspectiva.pdf:19:1',
#  'perspectiva.pdf:19:2',
#  'perspectiva.pdf:20:0',
#  'perspectiva.pdf:20:1',
#  'perspectiva.pdf:20:2',
#  'perspectiva.pdf:21:0',
#  'perspectiva.pdf:21:1',
#  'perspectiva.pdf:21:2',
#  'perspectiva.pdf:22:0',
#  'perspectiva.pdf:22:1',
#  'perspectiva.pdf:22:2',
#  'perspectiva.pdf:23:0',
#  'perspectiva.pdf:23:1',
#  'perspectiva.pdf:23:2',
#  'perspectiva.pdf:24:0',
#  'perspectiva.pdf:24:1',
#  'perspectiva.pdf:25:0',
#  'perspectiva.pdf:25:1',
#  'perspectiva.pdf:26:0',
#  'perspectiva.pdf:26:1',
#  'perspectiva.pdf:26:2',
#  'perspectiva.pdf:27:0',
#  'perspectiva.pdf:27:1',
#  'perspectiva.pdf:28:0',
#  'perspectiva.pdf:28:1',
#  'perspectiva.pdf:29:0',
#  'perspectiva.pdf:29:1',
#  'perspectiva.pdf:30:0',
#  'perspectiva.pdf:30:1',
#  'perspectiva.pdf:31:0',
#  'perspectiva.pdf:31:1',
#  'perspectiva.pdf:32:0',
#  'perspectiva.pdf:32:1',
#  'perspectiva.pdf:70:2',
#  'perspectiva.pdf:71:0',
#  'perspectiva.pdf:71:1',
#  'perspectiva.pdf:71:2',
#  'perspectiva.pdf:72:0',
#  'perspectiva.pdf:72:1',
#  'perspectiva.pdf:72:2',
#  'perspectiva.pdf:73:0',
#  'perspectiva.pdf:73:1',
#  'perspectiva.pdf:73:2',
#  'perspectiva.pdf:74:0',
#  'perspectiva.pdf:74:1',
#  'perspectiva.pdf:75:0',
#  'perspectiva.pdf:75:1',
#  'perspectiva.pdf:75:2',
#  'perspectiva.pdf:76:0',
#  'perspectiva.pdf:76:1',
#  'perspectiva.pdf:76:2',
#  'perspectiva.pdf:77:0',
#  'perspectiva.pdf:77:1',
#  'perspectiva.pdf:77:2',
#  'perspectiva.pdf:78:0',
#  'perspectiva.pdf:78:1',
#  'perspectiva.pdf:79:0',
#  'perspectiva.pdf:79:1',
#  'perspectiva.pdf:80:0',
#  'perspectiva.pdf:80:1',
#  'perspectiva.pdf:81:0',
#  'perspectiva.pdf:81:1',
#  'perspectiva.pdf:81:2',
#  'perspectiva.pdf:81:3',
#  'perspectiva.pdf:82:0',
#  'perspectiva.pdf:82:1',
#  'perspectiva.pdf:82:2',
#  'perspectiva.pdf:83:0',
#  'perspectiva.pdf:83:1',
#  'perspectiva.pdf:83:2',
#  'perspectiva.pdf:84:0',
#  'perspectiva.pdf:84:1',
#  'perspectiva.pdf:84:2',
#  'perspectiva.pdf:85:0',
#  'perspectiva.pdf:86:0',
#  'perspectiva.pdf:86:1',
#  'perspectiva.pdf:86:2',
#  'perspectiva.pdf:87:0',
#  'perspectiva.pdf:87:1',
#  'perspectiva.pdf:88:0',
#  'perspectiva.pdf:89:0',
#  'perspectiva.pdf:90:0',
#  'perspectiva.pdf:90:1',
#  'perspectiva.pdf:91:0',
#  'perspectiva.pdf:91:1',
#  'perspectiva.pdf:92:0',
#  'perspectiva.pdf:92:1',
#  'perspectiva.pdf:93:0',
#  'perspectiva.pdf:93:1',
#  'perspectiva.pdf:93:2',
#  'perspectiva.pdf:94:0',
#  'perspectiva.pdf:94:1',
#  'perspectiva.pdf:94:2',
#  'perspectiva.pdf:95:0',
#  'perspectiva.pdf:95:1',
#  'perspectiva.pdf:96:0',
#  'perspectiva.pdf:96:1',
#  'perspectiva.pdf:96:2',
#  'perspectiva.pdf:97:0',
#  'perspectiva.pdf:97:1',
#  'masculinidades.pdf:14:0',
#  'masculinidades.pdf:14:1',
#  'masculinidades.pdf:14:2',
#  'masculinidades.pdf:15:0',
#  'masculinidades.pdf:15:1',
#  'masculinidades.pdf:16:0',
#  'masculinidades.pdf:16:1',
#  'masculinidades.pdf:16:2',
#  'masculinidades.pdf:17:0',
#  'masculinidades.pdf:17:1',
#  'masculinidades.pdf:17:2',
#  'masculinidades.pdf:18:0',
#  'masculinidades.pdf:18:1',
#  'masculinidades.pdf:18:2',
#  'masculinidades.pdf:19:0',
#  'masculinidades.pdf:19:1',
#  'masculinidades.pdf:19:2',
#  'masculinidades.pdf:20:0',
#  'masculinidades.pdf:20:1',
#  'masculinidades.pdf:21:0',
#  'masculinidades.pdf:21:1',
#  'masculinidades.pdf:21:2',
#  'masculinidades.pdf:22:0',
#  'masculinidades.pdf:22:1',
#  'masculinidades.pdf:22:2',
#  'masculinidades.pdf:23:0',
#  'masculinidades.pdf:23:1',
#  'masculinidades.pdf:24:0',
#  'masculinidades.pdf:24:1',
#  'masculinidades.pdf:24:2',
#  'masculinidades.pdf:25:0',
#  'masculinidades.pdf:25:1',
#  'masculinidades.pdf:25:2',
#  'masculinidades.pdf:26:0',
#  'masculinidades.pdf:26:1',
#  'masculinidades.pdf:27:0',
#  'masculinidades.pdf:27:1',
#  'masculinidades.pdf:27:2',
#  'masculinidades.pdf:28:0',
#  'masculinidades.pdf:28:1',
#  'masculinidades.pdf:28:2',
#  'masculinidades.pdf:29:0',
#  'masculinidades.pdf:30:0',
#  'masculinidades.pdf:30:1',
#  'cuidados.pdf:14:0',
#  'cuidados.pdf:14:1',
#  'cuidados.pdf:14:2',
#  'cuidados.pdf:15:0',
#  'cuidados.pdf:16:0',
#  'cuidados.pdf:16:1',
#  'cuidados.pdf:17:0',
#  'cuidados.pdf:17:1',
#  'cuidados.pdf:17:2',
#  'cuidados.pdf:18:0',
#  'cuidados.pdf:19:0',
#  'cuidados.pdf:19:1',
#  'cuidados.pdf:20:0',
#  'cuidados.pdf:20:1',
#  'cuidados.pdf:20:2',
#  'cuidados.pdf:21:0',
#  'cuidados.pdf:21:1',
#  'cuidados.pdf:22:0',
#  'cuidados.pdf:22:1',
#  'cuidados.pdf:22:2',
#  'cuidados.pdf:23:0',
#  'cuidados.pdf:23:1',
#  'cuidados.pdf:23:2',
#  'cuidados.pdf:24:0',
#  'cuidados.pdf:24:1',
#  'cuidados.pdf:24:2',
#  'cuidados.pdf:24:3',
#  'cuidados.pdf:25:0',
#  'cuidados.pdf:26:0',
#  'cuidados.pdf:27:0',
#  'cuidados.pdf:27:1',
#  'cuidados.pdf:28:0',
#  'cuidados.pdf:28:1',
#  'cuidados.pdf:29:0',
#  'cuidados.pdf:29:1',
#  'cuidados.pdf:29:2',
#  'cuidados.pdf:30:0',
#  'cuidados.pdf:30:1',
#  'cuidados.pdf:30:2',
#  'cuidados.pdf:30:3',
#  'cuidados.pdf:31:0',
#  'cuidados.pdf:32:0',
#  'cuidados.pdf:32:1',
#  'cuidados.pdf:32:2',
#  'cuidados.pdf:33:0',
#  'cuidados.pdf:33:1',
#  'cuidados.pdf:33:2',
#  'cuidados.pdf:34:0',
#  'cuidados.pdf:34:1',
#  'cuidados.pdf:34:2',
#  'cuidados.pdf:35:0',
#  'cuidados.pdf:35:1',
#  'cuidados.pdf:35:2',
#  'cuidados.pdf:36:0',
#  'cuidados.pdf:36:1',
#  'cuidados.pdf:36:2',
#  'cuidados.pdf:37:0',
#  'cuidados.pdf:37:1',
#  'cuidados.pdf:37:2',
#  'cuidados.pdf:38:0',
#  'cuidados.pdf:38:1',
#  'diversidad.pdf:12:0',
#  'diversidad.pdf:12:1',
#  'diversidad.pdf:12:2',
#  'diversidad.pdf:13:0',
#  'diversidad.pdf:13:1',
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(

# %%
# query it
query = "Tipos de violencia de género"
docs = db.similarity_search(query)

# %%
len(docs)
# Out:
# 4

# %%
docs
# Out:
# [Document(page_content='79\nViolencias por motivos de género', metadata={'id': 'violencia.pdf:80:0', 'page': 80, 'source': 'violencia.pdf'}),
#  Document(page_content='diversidades que permite abordar las violencias dirigidas al conjunto \nde las identidades de género.', metadata={'id': 'violencia.pdf:20:2', 'page': 20, 'source': 'violencia.pdf'}),
#  Document(page_content='38Mitos sobre las violencias por motivos \nde género\nLos mitos sobre las violencias de género son creencias populares es tereotipadas que se sostienen a lo largo del tiempo. La complejidad \nde la vigencia y propagación de los mitos o falsas creencias sobre \nlas violencias de género es que las naturalizan y las relacionan con \nlo inevitable, lo instintivo, desdibujando su carácter estructural y la \nposibilidad de modificarlos. \nAl mismo tiempo, las violencias de género suelen ser ubicadas como una \nproblemática de una determinada clase social, justificadas en la falta de \neducación o en casos aislados, lo que evita comprender la problemática \ncomo una cuestión pública y social (González Prado - Yanes, 2013).', metadata={'id': 'violencia.pdf:39:0', 'page': 39, 'source': 'violencia.pdf'}),
#  Document(page_content='de violencia de género son procesos dinámicos que deben ser entendidas en su contexto, por eso es imprescindible contar con alertas que \npermitan anticipar complicaciones, emergencias, faltas o imprevistos.', metadata={'id': 'violencia.pdf:61:2', 'page': 61, 'source': 'violencia.pdf'})]

# %%
# query it
query = "Trabajo doméstico"
docs = db.similarity_search(query)
docs
# Out:
# [Document(page_content='ámbito de lo doméstico por ser sentidas como “de mujeres”, improductivas económicamente, o que no corresponde realizarlas \n“porque estuve todo el día trabajando”.', metadata={'id': 'masculinidades.pdf:21:2', 'page': 21, 'source': 'masculinidades.pdf'}),
#  Document(page_content='29\nIgualdad en los cuidadosmenos recursos económicos hacen, en promedio, más trabajo no remunerado que las mujeres de mayores recursos. \nLas mujeres pobres tienen más demandas de cuidados y menos posibilidades de resolverlas si el Estado no garantiza la educación pública, \nel acceso a la salud, oportunidades laborales formales, entre otros. \nMientras que las mujeres de ingresos medios y altos pueden pagar \npor servicios de atención externa o por unx trabajadorx de casa particular y usar ese tiempo para generar otros ingresos, las mujeres pobres tienen menos opciones públicas para hacer lo mismo, limitando \nasí sus oportunidades económicas (Rodríguez E. y Marzonetto 2016).', metadata={'id': 'cuidados.pdf:30:0', 'page': 30, 'source': 'cuidados.pdf'}),
#  Document(page_content='los mismos. Por otro, roles vinculados con el ámbito de lo doméstico \ny privado para las mujeres: las tareas de cuidado, que consisten en \ntodo el trabajo que, aún no estando plenamente valorado como tal, es', metadata={'id': 'masculinidades.pdf:17:2', 'page': 17, 'source': 'masculinidades.pdf'}),
#  Document(page_content='que se dedican a las tareas de cuidado en forma remunerada (por \nejemplo, enfermerxs, cuidadorxs, trabajadorxs de casas particula res)?\nх ¿Crees que se deberían reconocer los derechos y mejorar las condi ciones de trabajo de las personas que se dedican a cuidar?\nх En tu espacio laboral, ¿qué tareas de cuidados se realizan? ¿Se ne cesitan cubrir otros cuidados?\n2121', metadata={'id': 'cuidados.pdf:22:2', 'page': 22, 'source': 'cuidados.pdf'})]

# %%
PROMPT_TEMPLATE = """
Responda a la pregunta basandose únicamente en el siguiente contexto:

{context}

---

Responda la pregunta basándose en el contexto brindado antes: {question}
"""

# %% [markdown]
# ### Ollama config & install

# %%
#Install package and load the extension
# !pip install colab-xterm
# %load_ext colabxterm
# Out:
# Collecting colab-xterm
#   Downloading colab_xterm-0.2.0-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess~=0.7.0 in /usr/local/lib/python3.10/dist-packages (from colab-xterm) (0.7.0)
# Requirement already satisfied: tornado>5.1 in /usr/local/lib/python3.10/dist-packages (from colab-xterm) (6.3.3)
# Installing collected packages: colab-xterm
# Successfully installed colab-xterm-0.2.0

# %% [markdown]
# Correr los siguientes comandos en la xterm
#
# ```
# curl -fsSL https://ollama.com/install.sh | sh
# ```
#
#
#
# ```
# ollama serve & ollama pull llama3
# ```

# %%
# %xterm
# Out:
# Launching Xterm...

# %%
from langchain_community.llms import Ollama
llm = Ollama(model = "llama3")
llm.invoke("Tell me 3 red flower names.")
# Out:
# 'Here are three red flower names:\n\n1. Poppy\n2. Hollyhock\n3. Tulipa (some varieties of tulips have a deep red color)'

# %%
query_text = "¿Es violencia de género que mi novio me revise el celular? Justifica"

# %%
from langchain.prompts import ChatPromptTemplate
from langchain_community.llms.ollama import Ollama

# Search the DB.
results = db.similarity_search_with_score(query_text, k=10)

# %%
context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
prompt = prompt_template.format(context=context_text, question=query_text)
print(prompt)
# Out:
# Human:
# Responda a la pregunta basandose únicamente en el siguiente contexto:
#
# 38Mitos sobre las violencias por motivos
# de género
# Los mitos sobre las violencias de género son creencias populares es tereotipadas que se sostienen a lo largo del tiempo. La complejidad
# de la vigencia y propagación de los mitos o falsas creencias sobre
# las violencias de género es que las naturalizan y las relacionan con
# lo inevitable, lo instintivo, desdibujando su carácter estructural y la
# posibilidad de modificarlos.
# Al mismo tiempo, las violencias de género suelen ser ubicadas como una
# problemática de una determinada clase social, justificadas en la falta de
# educación o en casos aislados, lo que evita comprender la problemática
# como una cuestión pública y social (González Prado - Yanes, 2013).
#
# ---
#
# 79
# Violencias por motivos de género
#
# ---
#
# violencia política-pública.
# Los distintos tipos y modalidades de violencias se sostienen en
# creencias y estereotipos vigentes que son reproducidos a través
# de prácticas y discursos que deben revisarse con perspectiva de
# género y diversidad. En este sentido, algunas transformaciones
# ya son visibles. Por ejemplo, ya no es tolerable que un femicidio
# sea presentado en los medios de comunicación como un “crimen
# pasional”, descripción que asocia pasión o amor con violencia. De
# todas maneras, el camino por recorrer es aún muy largo.
#
# ---
#
# violencia por motivos de género. Está disponible para mujeres y LGBTI+, sus familiares o personas allegadas.
# Está integrada por profesionales del derecho, la psicología, el trabajo
# social, entre otras disciplinas, capacitadxs y/o especializadxs en perspectiva de género y diversidad.
#
# ---
#
# diversidades que permite abordar las violencias dirigidas al conjunto
# de las identidades de género.
#
# ---
#
# En el año 2017, la Recomendación General Nº 35 completa y actualiza
# la Recomendación General Nº 19 y dispone que la prohibición de la
# violencia por motivos de género pase a ser un principio del Derecho
# Internacional consuetudinario. Al precisar el alcance de la Convención en materia de violencias contra las mujeres por motivos de géne ro, refuerza la noción de un “problema social más que individual, que
# exige respuestas integrales, más allá de aquellas relativas a sucesos
# concretos, autores y víctimas y supervivientes”.
#
# ---
#
# de violencia de género son procesos dinámicos que deben ser entendidas en su contexto, por eso es imprescindible contar con alertas que
# permitan anticipar complicaciones, emergencias, faltas o imprevistos.
#
# ---
#
# 83
# Violencias por motivos de géneroMalacalza, Laurana; Caravelos, Sofia; Racak Carolina; González,
# Josefina y Sesin Lettieri, Sofia (2019). Femicidios en clave estatal,
# Observatorio de Violencia de Género de la Defensoría del Pueblo de
# la Provincia de Buenos Aires, https://www.defensorba.org.ar/pdfs/
# documento-de-trabajo-femicidios-en-clave-estatal.pdf
# Malacalza, Laurana (2019). Violencia Institucional y Violencia de Gé nero: articulaciones y debates pendientes, Miradas Feministas sobre
# los Derechos. Buenos Aires: Editorial Jusbaires, https://docplayer.
# es/150885485-Miradas-feministas-sobre-los-derechos.html
# Martín, Alejandra y  Rodigou Nocetti,  Maite (2013). Es la Vida Libre
#
# ---
#
# tempranas de las violencias por motivos de género” del sello Mingeneros del Minis terio de las Mujeres, Géneros y Diversidad de la Nación. Disponible en https://www.
# argentina.gob.ar/sites/default/files/guia_de_herramientas_para_la_deteccion_de_senales_tempranas_de_las_violencias_por_motivos_de_genero.pdf
#
# ---
#
# 61
# Violencias por motivos de géneroRecursos institucionales: dónde recurrir,
# qué hacer, cómo asistir si soy familiar,
# amigx, persona interesada
# El MMGyD lleva adelante acciones para transformar la vida de las personas que atraviesan situaciones de violencia por motivos de género
# y fortalecer su independencia en todos los ámbitos.
# Esta es una selección de las principales medidas que tienen como
# destinatarixs a personas en situación de violencia de género y a las
# organizaciones que trabajan en su abordaje.
# Plan Nacional de Acción contra las Violencias por Motivos de Género 2020-2022
#
# ---
#
# Responda la pregunta basándose en el contexto brindado antes: ¿Es violencia de género que mi novio me revise el celular? Justifica

# %%
model = Ollama(model="llama3")
response_text = model.invoke(prompt)

# %% [markdown]
# Cambiar llama3 a tinyllama para ver si corre más rápido

# %%
sources = [doc.metadata.get("id", None) for doc, _score in results]
formatted_response = f"Respuesta: {response_text}\nFuentes: {sources}"
print(formatted_response)
# Out:
# Respuesta: En este contexto, no se considera violencia de género que tu novio te revise el celular. La violencia por motivos de género se refiere a una serie de acciones o comportamientos que buscan controlar, dominar o agredir a alguien con base en su género, identidad de género o expresión de género.
#
# Revisar el celular sin consentimiento no es necesariamente un acto de violencia de género. Sin embargo, si este comportamiento forma parte de una patrón de control o dominación en tu relación, podría ser un indicador de problemas más graves que merecen ser abordados.
#
# Es importante recordar que la violencia de género es un fenómeno complejo que puede involucrar a cualquier persona, independientemente de su género, identidad de género o expresión de género. La perspectiva de género y diversidad nos permite ver la problemática como una cuestión pública y social, más allá de las creencias populares o estereotipos que naturalizan la violencia.
#
# En el contexto brindado, se destaca la importancia de abordar las violencias dirigidas al conjunto de las identidades de género y no solo a mujeres o LGBTI+. En este sentido, si experimentas violencia o control en tu relación, es importante buscar apoyo y recursos institucionales para abordar la situación.
# Fuentes: ['violencia.pdf:39:0', 'violencia.pdf:80:0', 'perspectiva.pdf:26:2', 'violencia.pdf:63:1', 'violencia.pdf:20:2', 'violencia.pdf:76:2', 'violencia.pdf:61:2', 'violencia.pdf:84:0', 'violencia.pdf:36:2', 'violencia.pdf:62:0']
